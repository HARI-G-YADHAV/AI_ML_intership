# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


newsgroups_data = fetch_20newsgroups(subset='train', remove=('headers', 'footers', 'quotes'))
texts = newsgroups_data.data[:100]  



bow_vectorizer = CountVectorizer(stop_words='english', max_features=50)
bow_matrix = bow_vectorizer.fit_transform(texts)
bow_df = pd.DataFrame(bow_matrix.toarray(), columns=bow_vectorizer.get_feature_names_out())
bow_freq = bow_df.sum().sort_values(ascending=False)

print("\n🔥 Top 10 Words (BoW):")
print(bow_freq.head(10))



tfidf_vectorizer = TfidfVectorizer(stop_words='english', max_features=50)
tfidf_matrix = tfidf_vectorizer.fit_transform(texts)
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=tfidf_vectorizer.get_feature_names_out())
top_tfidf_doc0 = tfidf_df.loc[0].sort_values(ascending=False)

print("\n🔍 Top TF-IDF Words for Doc 1:")
print(top_tfidf_doc0.head(10))


plt.figure(figsize=(10, 5))
sns.barplot(x=bow_freq.values[:10], y=bow_freq.index[:10])
plt.title("Top 10 Words by Frequency (BoW) in News Articles")
plt.xlabel("Frequency")
plt.tight_layout()
plt.show()
# Out:
# 🔥 Top 10 Words (BoW):
# people      48
# armenian    41
# does        34
# know        33
# use         30
# like        30
# don         29
# think       27
# years       27
# scsi        26
# dtype: int64
#
# 🔍 Top TF-IDF Words for Doc 1:
# car          0.933870
# day          0.220617
# years        0.220617
# know         0.174764
# 20           0.000000
# 10           0.000000
# armenians    0.000000
# army         0.000000
# armenian     0.000000
# 25           0.000000
# Name: 0, dtype: float64
